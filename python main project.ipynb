# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hr=pd.read_csv(r"C:\Users\dell\OneDrive\Desktop\HR_Attrition_dataset.csv")

# %%
hr
# Out:
#       Employee_ID  Age Attrition    Business_Travel              Department  \
# 0               1   56       Yes      Travel Rarely  Network Administration
# 1               2   46       Yes      Travel Rarely    Software Development
# 2               3   32        No          No Travel            Data Science
# 3               4   60       Yes  Travel Frequently            Data Science
# 4               5   25        No          No Travel  Network Administration
# ...           ...  ...       ...                ...                     ...
# 4995         4996   61        No      Travel Rarely  Network Administration
# 4996         4997   51        No      Travel Rarely    Software Development
# 4997         4998   37       Yes          No Travel            Data Science
# 4998         4999   55        No          No Travel          Cyber Security
# 4999         5000   41        No  Travel Frequently  Network Administration
#
# ...

# %%
hr.head()
# Out:
#    Employee_ID  Age Attrition    Business_Travel              Department  \
# 0            1   56       Yes      Travel Rarely  Network Administration
# 1            2   46       Yes      Travel Rarely    Software Development
# 2            3   32        No          No Travel            Data Science
# 3            4   60       Yes  Travel Frequently            Data Science
# 4            5   25        No          No Travel  Network Administration
#
#    Distance_From_Home   Education  Environment_Satisfaction  Gender  Salary  \
# 0                  24  Graduation                         5    Male  186630
# 1                  45      Degree                         5    Male   78553
# 2                  30    Master's                         3  Female  175003
# 3                  42  Graduation                         2  Female  100795
# 4                  26  Graduation                         4  Female   75256
#
#    ...  Job_Satisfaction  Marital_Status  \
# ...

# %%
hr.shape
# Out:
# (5000, 23)

# %%
hr.columns
# Out:
# Index(['Employee_ID', 'Age', 'Attrition', 'Business_Travel', 'Department',
#        'Distance_From_Home', 'Education', 'Environment_Satisfaction', 'Gender',
#        'Salary', 'Job_Involvement', 'Job_Level', 'Job_Role',
#        'Job_Satisfaction', 'Marital_Status',
#        'Number_of_Companies_Worked_previously', 'Overtime',
#        'Salary_Hike_in_percent', 'Total_working_years_experience',
#        'Work_life_balance', 'No_of_years_worked_at_current_company',
#        'No_of_years_in_current_role', 'Years_since_last_promotion'],
#       dtype='object')

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Employee_ID                            5000 non-null   int64
#  1   Age                                    5000 non-null   int64
#  2   Attrition                              5000 non-null   object
#  3   Business_Travel                        5000 non-null   object
#  4   Department                             5000 non-null   object
#  5   Distance_From_Home                     5000 non-null   int64
#  6   Education                              5000 non-null   object
#  7   Environment_Satisfaction               5000 non-null   int64
#  8   Gender                                 5000 non-null   object
#  9   Salary                                 5000 non-null   int64
# ...

# %%
hr.describe(include="all")
# Out:
#         Employee_ID          Age Attrition Business_Travel  \
# count   5000.000000  5000.000000      5000            5000
# unique          NaN          NaN         2               3
# top             NaN          NaN        No   Travel Rarely
# freq            NaN          NaN      4219            3012
# mean    2500.500000    40.560800       NaN             NaN
# std     1443.520003    13.165826       NaN             NaN
# min        1.000000    18.000000       NaN             NaN
# 25%     1250.750000    29.000000       NaN             NaN
# 50%     2500.500000    41.000000       NaN             NaN
# 75%     3750.250000    52.000000       NaN             NaN
# max     5000.000000    63.000000       NaN             NaN
#
#                   Department  Distance_From_Home   Education  \
# count                   5000         5000.000000        5000
# unique                     5                 NaN           5
# top     Software Development                 NaN  Graduation
# ...

# %%
hr.isnull().sum()
# Out:
# Employee_ID                              0
# Age                                      0
# Attrition                                0
# Business_Travel                          0
# Department                               0
# Distance_From_Home                       0
# Education                                0
# Environment_Satisfaction                 0
# Gender                                   0
# Salary                                   0
# Job_Involvement                          0
# Job_Level                                0
# Job_Role                                 0
# Job_Satisfaction                         0
# Marital_Status                           0
# Number_of_Companies_Worked_previously    0
# Overtime                                 0
# Salary_Hike_in_percent                   0
# Total_working_years_experience           0
# Work_life_balance                        0
# No_of_years_worked_at_current_company    0
# No_of_years_in_current_role              0
# ...

# %%
hr.groupby("Attrition")["Age"].mean()
# Out:
# Attrition
# No     40.582603
# Yes    40.443022
# Name: Age, dtype: float64

# %%
hr.groupby("Department")["Salary"].mean()
# Out:
# Department
# Cyber Security            117529.425403
# Data Science              117511.372490
# IT Services               113389.144855
# Network Administration    113126.154618
# Software Development      113933.833498
# Name: Salary, dtype: float64

# %%
print(hr.groupby("Department")["Attrition"].value_counts())
# Out:
# Department              Attrition
# Cyber Security          No           826
#                         Yes          166
# Data Science            No           836
#                         Yes          160
# IT Services             No           853
#                         Yes          148
# Network Administration  No           845
#                         Yes          151
# Software Development    No           859
#                         Yes          156
# Name: count, dtype: int64

# %%
hr.groupby("Department").size().reset_index(name="TotalEmployees")
# Out:
#                Department  TotalEmployees
# 0          Cyber Security             992
# 1            Data Science             996
# 2             IT Services            1001
# 3  Network Administration             996
# 4    Software Development            1015

# %%
hr.groupby(["Department", "Gender"]).size()
# Out:
# Department              Gender
# Cyber Security          Female    496
#                         Male      496
# Data Science            Female    513
#                         Male      483
# IT Services             Female    503
#                         Male      498
# Network Administration  Female    506
#                         Male      490
# Software Development    Female    515
#                         Male      500
# dtype: int64

# %%
hr.groupby("Job_Role")["Salary"].mean()
# Out:
# Job_Role
# Business Analyst     114283.569378
# Consultant           122783.640506
# Developer            113362.309179
# Director             117173.177885
# HR                   112062.851485
# Help Desk            110984.545232
# IT                   115072.709751
# Manager              115488.258537
# QA Analyst           115786.730159
# Software Engineer    112487.261176
# Support              113317.186275
# Technician           118466.983294
# Name: Salary, dtype: float64

# %% [markdown]
# ## Univariate

# %%
sns.histplot(hr["Age"], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(x="Department", hue="Attrition", data=hr)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.boxplot(x="Attrition",y="Salary",data=hr)
plt.show()

# %% [markdown]
#  ## outlayers

# %%
hr.boxplot()
# Out:
# <Axes: >

# %% [markdown]
#  ## Multivariate

# %%
sns.pairplot(hr[["Age","Salary","Total_working_years_experience","Attrition"]], hue="Attrition")
plt.show()
